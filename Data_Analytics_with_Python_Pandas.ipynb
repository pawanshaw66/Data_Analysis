# %% [markdown]
# <a href="https://colab.research.google.com/github/pawanshaw66/Data_Analysis/blob/main/Data_Analytics_with_Python_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dict1 ={'Name':['Priyang','Aadhya','Krisha','Vedant','Parshv',
                'Mittal','Archana'],
                'Marks':[98,np.nan,99,87,np.nan,83,99],
                'Gender':['Male','Female','Female','Male','Male',
                         'Female','Female'],
                'Email':['priyang@gmail.com','aadhya@gmail.com',
                        'krisha@gmail.com','vedant@yahoo.com','parshv@hotmail.com',
                         'mittal@yahoo.com','archana@yahoo.com']
               }
df1=pd.DataFrame(dict1)
df1
# Out:
#       Name  Marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2   Krisha   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   Parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
dict2={'Name':['Pawan'],
       'Marks':[98],
       'Gender':['Male'],
       'Email':['shawpawan66@gmail.com']}

# %%
# Top 3 rows of the dataset
df1.head(3)
# Out:
#       Name  Marks  Gender              Email
# 0  Priyang   98.0    Male  priyang@gmail.com
# 1   Aadhya    NaN  Female   aadhya@gmail.com
# 2   Krisha   99.0  Female   krisha@gmail.com

# %%
# Last 3 rows of the dataset
df1.tail(3)
# Out:
#       Name  Marks  Gender               Email
# 4   Parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
# All rows except the last 2 rows
df1.head(-2)
# Out:
#       Name  Marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2   Krisha   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   Parshv    NaN    Male  parshv@hotmail.com

# %%
# All rows except first 3 rows
df1.tail(3)
# Out:
#       Name  Marks  Gender               Email
# 4   Parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
# Find the shape of the dataset
df1.shape
# Out:
# (7, 4)

# %%
print("Number of rows:",df1.shape[0])
print("Number of columns:",df1.shape[1])
# Out:
# Number of rows: 7
# Number of columns: 4

# %%
# get information about our dataset
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   5 non-null      float64
#  2   Gender  7 non-null      object
#  3   Email   7 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 352.0+ bytes

# %%
# check null values 
df1.isnull()
# Out:
#     Name  Marks  Gender  Email
# 0  False  False   False  False
# 1  False   True   False  False
# 2  False  False   False  False
# 3  False  False   False  False
# 4  False   True   False  False
# 5  False  False   False  False
# 6  False  False   False  False

# %%
df1.isnull().sum()
# Out:
# Name      0
# Marks     2
# Gender    0
# Email     0
# dtype: int64

# %%
# get overall statistics about the describe
df1.describe()   # shows only numerical value data
# Out:
#            Marks
# count   5.000000
# mean   93.200000
# std     7.628892
# min    83.000000
# 25%    87.000000
# 50%    98.000000
# 75%    99.000000
# max    99.000000

# %%
df1.describe(include='all')
# Out:
#            Name      Marks  Gender              Email
# count         7   5.000000       7                  7
# unique        7        NaN       2                  7
# top     Priyang        NaN  Female  priyang@gmail.com
# freq          1        NaN       4                  1
# mean        NaN  93.200000     NaN                NaN
# std         NaN   7.628892     NaN                NaN
# min         NaN  83.000000     NaN                NaN
# 25%         NaN  87.000000     NaN                NaN
# 50%         NaN  98.000000     NaN                NaN
# 75%         NaN  99.000000     NaN                NaN
# max         NaN  99.000000     NaN                NaN

# %%
# find unique values from the gender column
df1['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
# find the number of unique values from the gender column
df1['Gender'].nunique()
# Out:
# 2

# %%
df1.nunique()
# Out:
# Name      7
# Marks     4
# Gender    2
# Email     7
# dtype: int64

# %%
# Display count of unique values in gender column
df1['Gender'].value_counts()
# Out:
# Female    4
# Male      3
# Name: Gender, dtype: int64

# %%
# Handling missing values
df1.fillna(0)
# Out:
#       Name  Marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    0.0  Female    aadhya@gmail.com
# 2   Krisha   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   Parshv    0.0    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
df1['Marks'] = df1['Marks'].fillna(df1['Marks'].mean())

# %%
df1
# Out:
#       Name  Marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya   93.2  Female    aadhya@gmail.com
# 2   Krisha   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   Parshv   93.2    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
# Marks between 80 to 90
(df1['Marks'] >= 80) & (df1['Marks']<=90)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# Name: Marks, dtype: bool

# %%
sum((df1['Marks'] >= 80) & (df1['Marks']<=90))
# Out:
# 2

# %%
df1['Marks'].between(80,90)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# Name: Marks, dtype: bool

# %%
# Name of the students with marks
df1[df1['Marks'].min() == df1['Marks']]['Name']
# Out:
# 5    Mittal
# Name: Name, dtype: object

# %%
# Top 5 students by their marks
df1.nlargest(5,'Marks')['Name']
# Out:
# 2     Krisha
# 6    Archana
# 0    Priyang
# 1     Aadhya
# 4     Parshv
# Name: Name, dtype: object

# %%
df1.nlargest(5,'Marks')[['Name','Marks']]
# Out:
#       Name  Marks
# 2   Krisha   99.0
# 6  Archana   99.0
# 0  Priyang   98.0
# 1   Aadhya   93.2
# 4   Parshv   93.2

# %%
df1.sort_values(by='Marks',ascending=False).head()[['Name','Marks']]
# Out:
#       Name  Marks
# 2   Krisha   99.0
# 6  Archana   99.0
# 0  Priyang   98.0
# 1   Aadhya   93.2
# 4   Parshv   93.2

# %%
# Find average marks
df1['Marks'].mean()
# Out:
# 93.2

# %%
df1['Marks'].max()
# Out:
# 99.0

# %%
df1['Marks'].min()
# Out:
# 83.0

# %%
def marks(x):
  return x/2

# %%
df1['Half_Marks'] = df1['Marks'].apply(marks)

# %%
df1['Half_Marks']
# Out:
# 0    49.0
# 1    46.6
# 2    49.5
# 3    43.5
# 4    46.6
# 5    41.5
# 6    49.5
# Name: Half_Marks, dtype: float64

# %%
df1
# Out:
#       Name  Marks  Gender               Email  Half_Marks
# 0  Priyang   98.0    Male   priyang@gmail.com        49.0
# 1   Aadhya   93.2  Female    aadhya@gmail.com        46.6
# 2   Krisha   99.0  Female    krisha@gmail.com        49.5
# 3   Vedant   87.0    Male    vedant@yahoo.com        43.5
# 4   Parshv   93.2    Male  parshv@hotmail.com        46.6
# 5   Mittal   83.0  Female    mittal@yahoo.com        41.5
# 6  Archana   99.0  Female   archana@yahoo.com        49.5

# %%
df1['Male_Female'] = df1['Gender'].map({'Male':1,'Female':0})

# %%
df1['Male_Female']
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    1
# 5    0
# 6    0
# Name: Male_Female, dtype: int64

# %%
df1
# Out:
#       Name  Marks  Gender               Email  Half_Marks  Male_Female
# 0  Priyang   98.0    Male   priyang@gmail.com        49.0            1
# 1   Aadhya   93.2  Female    aadhya@gmail.com        46.6            0
# 2   Krisha   99.0  Female    krisha@gmail.com        49.5            0
# 3   Vedant   87.0    Male    vedant@yahoo.com        43.5            1
# 4   Parshv   93.2    Male  parshv@hotmail.com        46.6            1
# 5   Mittal   83.0  Female    mittal@yahoo.com        41.5            0
# 6  Archana   99.0  Female   archana@yahoo.com        49.5            0

# %%
df1.drop('Male_Female',axis=1)   # axis=1 show column
# Out:
#       Name  Marks  Gender               Email  Half_Marks
# 0  Priyang   98.0    Male   priyang@gmail.com        49.0
# 1   Aadhya   93.2  Female    aadhya@gmail.com        46.6
# 2   Krisha   99.0  Female    krisha@gmail.com        49.5
# 3   Vedant   87.0    Male    vedant@yahoo.com        43.5
# 4   Parshv   93.2    Male  parshv@hotmail.com        46.6
# 5   Mittal   83.0  Female    mittal@yahoo.com        41.5
# 6  Archana   99.0  Female   archana@yahoo.com        49.5

# %%
df1
# Out:
#       Name  Marks  Gender               Email  Half_Marks  Male_Female
# 0  Priyang   98.0    Male   priyang@gmail.com        49.0            1
# 1   Aadhya   93.2  Female    aadhya@gmail.com        46.6            0
# 2   Krisha   99.0  Female    krisha@gmail.com        49.5            0
# 3   Vedant   87.0    Male    vedant@yahoo.com        43.5            1
# 4   Parshv   93.2    Male  parshv@hotmail.com        46.6            1
# 5   Mittal   83.0  Female    mittal@yahoo.com        41.5            0
# 6  Archana   99.0  Female   archana@yahoo.com        49.5            0

# %%
df1.drop('Male_Female',axis=1, inplace=True)    # Using inplace we permanetaly drop the column 'Male_Female'

# %%
df1
# Out:
#       Name  Marks  Gender               Email  Half_Marks
# 0  Priyang   98.0    Male   priyang@gmail.com        49.0
# 1   Aadhya   93.2  Female    aadhya@gmail.com        46.6
# 2   Krisha   99.0  Female    krisha@gmail.com        49.5
# 3   Vedant   87.0    Male    vedant@yahoo.com        43.5
# 4   Parshv   93.2    Male  parshv@hotmail.com        46.6
# 5   Mittal   83.0  Female    mittal@yahoo.com        41.5
# 6  Archana   99.0  Female   archana@yahoo.com        49.5

# %%
df1
# Out:
#       Name  Marks  Gender               Email  Half_Marks
# 0  Priyang   98.0    Male   priyang@gmail.com        49.0
# 1   Aadhya   93.2  Female    aadhya@gmail.com        46.6
# 2   Krisha   99.0  Female    krisha@gmail.com        49.5
# 3   Vedant   87.0    Male    vedant@yahoo.com        43.5
# 4   Parshv   93.2    Male  parshv@hotmail.com        46.6
# 5   Mittal   83.0  Female    mittal@yahoo.com        41.5
# 6  Archana   99.0  Female   archana@yahoo.com        49.5

# %%
df1.sort_values(by='Marks',ascending=False)
# Out:
#       Name  Marks  Gender               Email  Half_Marks
# 2   Krisha   99.0  Female    krisha@gmail.com        49.5
# 6  Archana   99.0  Female   archana@yahoo.com        49.5
# 0  Priyang   98.0    Male   priyang@gmail.com        49.0
# 1   Aadhya   93.2  Female    aadhya@gmail.com        46.6
# 4   Parshv   93.2    Male  parshv@hotmail.com        46.6
# 3   Vedant   87.0    Male    vedant@yahoo.com        43.5
# 5   Mittal   83.0  Female    mittal@yahoo.com        41.5

# %%
df1
# Out:
#       Name  Marks  Gender               Email  Half_Marks
# 0  Priyang   98.0    Male   priyang@gmail.com        49.0
# 1   Aadhya   93.2  Female    aadhya@gmail.com        46.6
# 2   Krisha   99.0  Female    krisha@gmail.com        49.5
# 3   Vedant   87.0    Male    vedant@yahoo.com        43.5
# 4   Parshv   93.2    Male  parshv@hotmail.com        46.6
# 5   Mittal   83.0  Female    mittal@yahoo.com        41.5
# 6  Archana   99.0  Female   archana@yahoo.com        49.5

# %%
# name and marks for the female students
df1['Gender'] == 'Female'
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# Name: Gender, dtype: bool

# %%
df1[df1['Gender'] == 'Female']
# Out:
#       Name  Marks  Gender              Email  Half_Marks
# 1   Aadhya   93.2  Female   aadhya@gmail.com        46.6
# 2   Krisha   99.0  Female   krisha@gmail.com        49.5
# 5   Mittal   83.0  Female   mittal@yahoo.com        41.5
# 6  Archana   99.0  Female  archana@yahoo.com        49.5

# %%
df1[df1['Gender'] == 'Female'][['Name','Marks']]
# Out:
#       Name  Marks
# 1   Aadhya   93.2
# 2   Krisha   99.0
# 5   Mittal   83.0
# 6  Archana   99.0

# %%
df1[df1['Gender'].isin(['Female'])][['Name','Marks']]
# Out:
#       Name  Marks
# 1   Aadhya   93.2
# 2   Krisha   99.0
# 5   Mittal   83.0
# 6  Archana   99.0

# %%
# Rename the marks columns
df1.rename(columns = {'Marks':"Final_Score"})
# Out:
#       Name  Final_Score  Gender               Email  Half_Marks
# 0  Priyang         98.0    Male   priyang@gmail.com        49.0
# 1   Aadhya         93.2  Female    aadhya@gmail.com        46.6
# 2   Krisha         99.0  Female    krisha@gmail.com        49.5
# 3   Vedant         87.0    Male    vedant@yahoo.com        43.5
# 4   Parshv         93.2    Male  parshv@hotmail.com        46.6
# 5   Mittal         83.0  Female    mittal@yahoo.com        41.5
# 6  Archana         99.0  Female   archana@yahoo.com        49.5

# %%
df2 = pd.DataFrame(dict2)

# %%
df2
# Out:
#     Name  Marks Gender                  Email
# 0  Pawan     98   Male  shawpawan66@gmail.com

# %%
df3 = pd.concat([df1,df2],ignore_index=True)

# %%
df3
# Out:
#       Name  Marks  Gender                  Email  Half_Marks
# 0  Priyang   98.0    Male      priyang@gmail.com        49.0
# 1   Aadhya   93.2  Female       aadhya@gmail.com        46.6
# 2   Krisha   99.0  Female       krisha@gmail.com        49.5
# 3   Vedant   87.0    Male       vedant@yahoo.com        43.5
# 4   Parshv   93.2    Male     parshv@hotmail.com        46.6
# 5   Mittal   83.0  Female       mittal@yahoo.com        41.5
# 6  Archana   99.0  Female      archana@yahoo.com        49.5
# 7    Pawan   98.0    Male  shawpawan66@gmail.com         NaN

# %%
# loc & iloc
df1.loc[:,'Marks':'Gender']
# Out:
#    Marks  Gender
# 0   98.0    Male
# 1   93.2  Female
# 2   99.0  Female
# 3   87.0    Male
# 4   93.2    Male
# 5   83.0  Female
# 6   99.0  Female

# %%
df1.iloc[:,3]
# Out:
# 0     priyang@gmail.com
# 1      aadhya@gmail.com
# 2      krisha@gmail.com
# 3      vedant@yahoo.com
# 4    parshv@hotmail.com
# 5      mittal@yahoo.com
# 6     archana@yahoo.com
# Name: Email, dtype: object

# %%
df1['Name'] + ' , ' + df1['Marks'].apply(str)
# Out:
# 0    Priyang , 98.0
# 1     Aadhya , 93.2
# 2     Krisha , 99.0
# 3     Vedant , 87.0
# 4     Parshv , 93.2
# 5     Mittal , 83.0
# 6    Archana , 99.0
# dtype: object

# %%
# find the highest average value as per gender
df1.groupby('Gender')['Marks'].mean().to_frame()
# Out:
#             Marks
# Gender
# Female  93.550000
# Male    92.733333
